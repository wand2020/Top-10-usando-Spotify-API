# %% [markdown]
# # TOP 10 DO SPOTIFY

# %% [markdown]
# Atualmente tenho sido um usuário frequente do aplicativo de música Spotify que foi lançado em 2008.
# Eu sou apaixonado por ouvir músicas dos mais diversos estilos e me despertou a curiosidade de compreender
# qual cantor os usuários do Spotify tem mais ouvido atualmente, e quais características do som estariam relacionadas a estes cantores, que possivelmente justifique na atualidade serem os mais ouvidos por usuários
# do Spotify.
#
# No intuito de ter uma visão em cantores do gênero masculino e feminino mais ouvidos, decidi pautar a minha pesquisa nos 10 cantores e nas 10 cantoras mais ouvidas no aplicativo do Spotify em julho de 2020. Esta pesquisa foi realizada em 05 de agosto de 2020 nos sites:
#
#     https://en.wikipedia.org/wiki/List_of_most-streamed_artists_on_Spotify.
#
#     https://rateyourmusic.com/list/NicklasWachter/spotify-top-100-artists-chart-29th_july_2020/ .
#
# A lista nos sites contém os artistas mais transmitidos.
# Para realizar este estudo, foi coletado de cada cantor, o top 10 de suas músicas estabelecidas pelo Spotify.
# O aplicativo fornece medidas de "audio features" e informações para cada uma das faixas de música idenficado por um id exclusivo. E é através destas medidas que será pautado o estudo deste projeto, são elas (preferi manter  o texto original do Spotify):
#
# **duration_ms** - the duration of the track in milliseconds,
#
# **key** - the estimated overall key of the track. Integers map to pitches using standard Pitch Class notation,
#
# **mode** - mode indicates the modality (major or minor) of a track, the type of scale from which its melodic content is derived. Major is represented by 1 and minor is 0,
#
# **time_signature** - an estimated overall time signature of a track. The time signature (meter) is a notational convention to specify how many beats are in each bar (or measure),
#
# **acousticness** - a confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic,
#
# **danceability** - danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable,
#
# **energy** - energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy,
#
# **instrumentalness** - predicts whether a track contains no vocals. “Ooh” and “aah” sounds are treated as instrumental in this context. Rap or spoken word tracks are clearly “vocal”. The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content. Values above 0.5 are intended to represent instrumental tracks, but confidence is higher as the value approaches 1.0,
#
# **liveness** - detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live. A value above 0.8 provides strong likelihood that the track is live,
#
# **loudness** - the overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks. Loudness is the quality of a sound that is the primary psychological correlate of physical strength (amplitude). Values typical range between -60 and 0 db,
#
# **speechiness** - speechiness detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks,
#
# **valence** - a measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry),
#
# **tempo** - the overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration.
#
# Neste projeto vai ser mantido a representação de números estabelecida pelo spotify por pontos
# (sendo que no Brasil a representação numérica é por vírgula, ou seja, "0.8", no Brasil representa "0,8").
#
# A descrição deste projeto se dividirá em três passos:
#
# Passo 1: O algoritmo para coleta dos dados.
#
# Passo 2: A análise gráfica dos dados.
#
# Passo 3: O uso do Machine Learning.
#
# É importante ressaltar que este estudo tem como referência o projeto desenvolvido
# pelo Jonathan Cabreira - https://github.com/jmcabreira/A-Music-Taste-Analysis-Using-Spotify-API-and-Python
# e o curso de Data Science do Zero.

# %% [markdown]
# # Passo 1 - Obtendo os dados do spotify.

# %%
# Importando dados
import spotipy
import spotipy.util as util
import pandas as pd 
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#Solicitação do usuário e da senha
CLIENT_ID = 'seu id de usuário'
CLIENT_SECRET = 'sua senha de usuário'

# %%
client_credentials_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# # Lista de uri dos cantores

# %%
#Modelo para coletar dados:
#CANTORAS
F1_singer = 'Dua Lipa'
F1_uri= 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'
F2_singer = 'Ariana Grande'
F2_uri= 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR'
F3_singer = 'Lady Gaga'
F3_uri= 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'
F4_singer = 'Halsey'
F4_uri= 'spotify:artist:26VFTg2z8YR0cCuwLzESi2'
F5_singer = 'Nicki Minaj'
F5_uri= 'spotify:artist:0hCNtLu0JehylgoiP8L4Gh'
F6_singer = 'Taylor Swift'
F6_uri= 'spotify:artist:06HL4z0CvFAxyc27GXpf02'
F7_singer = 'Billie Eilish'
F7_uri= 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'
F8_singer = 'Camila Cabello'
F8_uri= 'spotify:artist:4nDoRrQiYLoBzwC5BhVJzF'
F9_singer = 'Beyonce'
F9_uri= 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'
F10_singer = 'Rihanna'
F10_uri= 'spotify:artist:5pKCCKE2ajJHZ9KAiaK11H'

#CANTORES
M1_singer = 'Drake'
M1_uri= 'spotify:artist:3TVXtAsR1Inumwj472S9r4'
M2_singer = 'The Weeknd'
M2_uri= 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'
M3_singer = 'J Balvin'
M3_uri= 'spotify:artist:1vyhD5VmyZ7KMfW5gqLgo5'
M4_singer = 'Justin Bieber'
M4_uri= 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'
M5_singer = 'Ed Sheeran'
M5_uri= 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'
M6_singer = 'Marshmello'
M6_uri= 'spotify:artist:64KEffDW9EtZ1y2vBYgq8T'
M7_singer = 'Khalid'
M7_uri= 'spotify:artist:6LuN9FCkKOj5PcnpouEgny'
M8_singer = 'Travis Scoot'
M8_uri= 'spotify:artist:0Y5tJX1MQlPlqiwlOH1tJY'
M9_singer = 'Jason Derullo'
M9_uri= 'spotify:artist:07YZf4WDAMNwqr4jfgOZ8y'
M10_singer = 'Juice WRLD'
M10_uri= 'spotify:artist:4MCBfE4596Uoi2O4DtmEMz'

# %%
# Função para obter os audio features
def analyze_artist(artist_uri):
    
    # Create empty dataframe
    playlist_features_list = ["track_name", "track_id", "acousticness", 
                             "danceability", "energy", "key", "loudness", "mode", "speechiness",
                             "instrumentalness", "liveness", "valence", "tempo", "duration_ms", "time_signature"]
    playlist_df = pd.DataFrame(columns = playlist_features_list)
    
    # Create empty dict
    playlist_features = {}
    
    # Loop through every track in the playlist, extract features and append the features to the playlist df
    results = sp.artist_top_tracks(artist_uri)
    for track in results['tracks'][:10]:
        # Get metadata
#        playlist_features["artist"] = track["album"][0]["name"]
#        playlist_features["album"] = track["album"]["name"]
        playlist_features["track_name"] = track["name"]
        playlist_features["track_id"] = track["id"]
        # Get audio features
        audio_features = sp.audio_features(playlist_features["track_id"])[0]
        for feature in playlist_features_list[2:]:
            playlist_features[feature] = audio_features[feature]
        
        # Concat the dfs
        track_df = pd.DataFrame(playlist_features, index = [0])
        playlist_df = pd.concat([playlist_df, track_df], ignore_index = True)
        
    return playlist_df

# %%
#Modelo de como baixar um dos dados 
F1_df = analyze_artist(F1_uri)
F1_df = pd.DataFrame(F1_df)
#Criando uma coluna com o nome do cantor
yF1 = []
Target_F=[]

for i in range(1,11):
    yF1.append(F1_singer) 
    Target_F.append('F')
    
yF1=pd.DataFrame(yF1, columns=['Artist'])
Target_F=pd.DataFrame(Target_F, columns=['Target'])
playlist = pd.concat([F1_df, yF1, Target_F], axis=1)
playlist.to_csv("Cantor.csv", index = False)

# %%
playlist.head()
# Out:
#                        track_name                track_id  acousticness  \
# 0  UN DIA (ONE DAY) (Feat. Tainy)  0EhpEsp4L0oRGM0vmeaN5e       0.00536
# 1                 Don't Start Now  3PfIrDoz19wz7qK7tYeu62       0.01230
# 2                  Break My Heart  017PF4Q3l4DBUiWoXk4OWT       0.16700
# 3        One Kiss (with Dua Lipa)  7ef4DlsgrMEH11cDZd32M6       0.03700
# 4                        Physical  3AzjcOeAmA57TIOr9zF1ZW       0.01370
#
#    danceability  energy key  loudness mode  speechiness instrumentalness  \
# 0         0.571   0.693   6    -8.234    0       0.0545                0
# 1         0.793   0.793  11    -4.521    0       0.0830                0
# 2         0.730   0.729   4    -3.434    0       0.0883         1.39e-06
# 3         0.791   0.862   9    -3.240    0       0.1100         2.19e-05
# 4         0.647   0.844   0    -3.756    1       0.0457         0.000658
#
#    liveness  valence    tempo duration_ms time_signature    Artist Target
# ...
